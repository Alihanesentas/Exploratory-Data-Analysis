# %%
import seaborn as sns 
flights = sns.load_dataset('flights')
df = flights.copy()
df.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
df.shape
# Out:
# (144, 3)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   year        144 non-null    int64
#  1   month       144 non-null    category
#  2   passengers  144 non-null    int64
# dtypes: category(1), int64(2)
# memory usage: 2.9 KB

# %%
df["passengers"].describe()
# Out:
# count    144.000000
# mean     280.298611
# std      119.966317
# min      104.000000
# 25%      180.000000
# 50%      265.500000
# 75%      360.500000
# max      622.000000
# Name: passengers, dtype: float64

# %%
df=df.pivot("month","year","passengers")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 df=df.pivot("month","year","passengers")
#
# TypeError: DataFrame.pivot() takes 1 positional argument but 4 were given

# %%
df
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# Dec     118   140   166   194   201   229   278   306   336   337   405   432

# %%
sns.heatmap(df)
# Out:
# <Axes: xlabel='year', ylabel='month'>

# %%
sns.heatmap(df,annot=True,fmt="d")
# Out:
# <Axes: xlabel='year', ylabel='month'>

# %%
sns.heatmap(df,annot=True,fmt="d",linewidths=0.5)
# Out:
# <Axes: xlabel='year', ylabel='month'>

# %%
import seaborn as sns
fmri = sns.load_dataset("fmri")
df = fmri.copy()
df.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
df.shape
# Out:
# (1064, 5)

# %%
df["timepoint"].describe()
# Out:
# count    1064.000000
# mean        9.000000
# std         5.479801
# min         0.000000
# 25%         4.000000
# 50%         9.000000
# 75%        14.000000
# max        18.000000
# Name: timepoint, dtype: float64

# %%
df["signal"].describe()
# Out:
# count    1064.000000
# mean        0.003540
# std         0.093930
# min        -0.255486
# 25%        -0.046070
# 50%        -0.013653
# 75%         0.024293
# max         0.564985
# Name: signal, dtype: float64

# %%
df["subject"].describe()
# Out:
# count     1064
# unique      14
# top        s13
# freq        76
# Name: subject, dtype: object

# %%
df.groupby("timepoint")["signal"].count()
# Out:
# timepoint
# 0     56
# 1     56
# 2     56
# 3     56
# 4     56
# 5     56
# 6     56
# 7     56
# 8     56
# 9     56
# 10    56
# 11    56
# 12    56
# 13    56
# 14    56
# 15    56
# 16    56
# 17    56
# 18    56
# Name: signal, dtype: int64

# %%
df.groupby("signal").count()
# Out:
#            subject  timepoint  event  region
# signal
# -0.255486        1          1      1       1
# -0.238474        1          1      1       1
# -0.224351        1          1      1       1
# -0.181241        1          1      1       1
# -0.178510        1          1      1       1
# ...            ...        ...    ...     ...
#  0.455575        1          1      1       1
#  0.460896        1          1      1       1
#  0.476055        1          1      1       1
#  0.494787        1          1      1       1
#  0.564985        1          1      1       1
#
# [1064 rows x 4 columns]

# %%
df.groupby("timepoint")["signal"].describe()
# Out:
#            count      mean       std       min       25%       50%       75%  \
# timepoint
# 0           56.0 -0.016662  0.028326 -0.064454 -0.039169 -0.018382  0.003539
# 1           56.0 -0.025002  0.030641 -0.082174 -0.046299 -0.024533 -0.005388
# 2           56.0 -0.012873  0.035440 -0.110565 -0.034944 -0.013183  0.009318
# 3           56.0  0.034446  0.058260 -0.089708 -0.001157  0.028430  0.061840
# 4           56.0  0.098194  0.092838 -0.046347  0.030912  0.070166  0.144911
# 5           56.0  0.137725  0.123353 -0.017946  0.042762  0.096535  0.211638
# 6           56.0  0.127515  0.137332 -0.054405  0.022409  0.068850  0.218919
# 7           56.0  0.075660  0.129704 -0.108222 -0.016252  0.032486  0.144781
# 8           56.0  0.013420  0.104216 -0.181241 -0.049453 -0.012834  0.030396
# 9           56.0 -0.032041  0.072728 -0.152929 -0.075693 -0.038496  0.008717
# 10          56.0 -0.053685  0.053148 -0.176453 -0.078893 -0.052906 -0.015302
# 11          56.0 -0.058194  0.053828 -0.238474 -0.093127 -0.045699 -0.022522
# 12          56.0 -0.052526  0.056991 -0.255486 -0.090391 -0.042294 -0.016239
# 13          56.0 -0.043532  0.053598 -0.224351 -0.069285 -0.031612 -0.012958
# 14          56.0 -0.033660  0.045983 -0.169312 -0.055110 -0.022165 -0.006797
# 15          56.0 -0.025880  0.039092 -0.134828 -0.050536 -0.018207  0.000486
# 16          56.0 -0.022414  0.035035 -0.131641 -0.041122 -0.020777 -0.001380
# 17          56.0 -0.021368  0.034797 -0.121574 -0.042946 -0.017070 -0.000026
# 18          56.0 -0.021867  0.036322 -0.103513 -0.046781 -0.020225 -0.002821
#
#                 max
# timepoint
# 0          0.074399
# 1          0.063558
# 2          0.077277
# 3          0.185581
# 4          0.346775
# 5          0.476055
# 6          0.564985
# 7          0.494787
# 8          0.337143
# 9          0.221716
# 10         0.089231
# 11         0.030528
# 12         0.055766
# 13         0.059510
# 14         0.050133
# 15         0.047102
# 16         0.057105
# 17         0.073757
# 18         0.090520

# %%
sns.lineplot(x="timepoint",y="signal",data=df)
# Out:
# <Axes: xlabel='timepoint', ylabel='signal'>

# %%
sns.lineplot(x="timepoint",y="signal",hue="event",data=df)
# Out:
# <Axes: xlabel='timepoint', ylabel='signal'>

# %% [markdown]
# Stim is affectly dataset strdr,mean

# %%
sns.lineplot(x="timepoint",y="signal",hue="event",style="event",data=df)
# Out:
# <Axes: xlabel='timepoint', ylabel='signal'>

# %%
sns.lineplot(x="timepoint",
             y="signal",
             hue="event",
             data=df,
             style="event",
             markers=True,
             dashes=False)
# Out:
# <Axes: xlabel='timepoint', ylabel='signal'>

# %%
sns.lineplot(x="timepoint",
             y="signal",
             hue="region",
             data=df,
             style="event",
             markers=True,
             dashes=False)
# Out:
# <Axes: xlabel='timepoint', ylabel='signal'>

# %% [markdown]
# Basic Time Series

# %%
# !pip install pandas_datareader
# Out:
# Collecting pandas_datareader
#   Obtaining dependency information for pandas_datareader from https://files.pythonhosted.org/packages/3f/16/56c9d648b503619ebe96f726b5f642b68e299b34162ed2d6faa9d7966b7d/pandas_datareader-0.10.0-py3-none-any.whl.metadata
#   Downloading pandas_datareader-0.10.0-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: lxml in /Users/alihan/anaconda3/lib/python3.11/site-packages (from pandas_datareader) (4.9.3)
# Requirement already satisfied: pandas>=0.23 in /Users/alihan/anaconda3/lib/python3.11/site-packages (from pandas_datareader) (2.0.3)
# Requirement already satisfied: requests>=2.19.0 in /Users/alihan/anaconda3/lib/python3.11/site-packages (from pandas_datareader) (2.31.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/alihan/anaconda3/lib/python3.11/site-packages (from pandas>=0.23->pandas_datareader) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/alihan/anaconda3/lib/python3.11/site-packages (from pandas>=0.23->pandas_datareader) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /Users/alihan/anaconda3/lib/python3.11/site-packages (from pandas>=0.23->pandas_datareader) (2023.3)
# Requirement already satisfied: numpy>=1.21.0 in /Users/alihan/anaconda3/lib/python3.11/site-packages (from pandas>=0.23->pandas_datareader) (1.24.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/alihan/anaconda3/lib/python3.11/site-packages (from requests>=2.19.0->pandas_datareader) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/alihan/anaconda3/lib/python3.11/site-packages (from requests>=2.19.0->pandas_datareader) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/alihan/anaconda3/lib/python3.11/site-packages (from requests>=2.19.0->pandas_datareader) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/alihan/anaconda3/lib/python3.11/site-packages (from requests>=2.19.0->pandas_datareader) (2023.11.17)
# Requirement already satisfied: six>=1.5 in /Users/alihan/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas>=0.23->pandas_datareader) (1.16.0)
# Downloading pandas_datareader-0.10.0-py3-none-any.whl (109 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 109.5/109.5 kB 530.2 kB/s eta 0:00:00a 0:00:01
# Installing collected packages: pandas_datareader
# Successfully installed pandas_datareader-0.10.0

# %%
import pandas_datareader as pr

# %%
# !pip install yfinance --upgrade --no-cache-dir
import yfinance as yf
 
import pandas_datareader as pr
import pandas as pd
# Out:
# Requirement already satisfied: yfinance in /Users/alihan/anaconda3/lib/python3.11/site-packages (0.2.37)
# Requirement already satisfied: pandas>=1.3.0 in /Users/alihan/anaconda3/lib/python3.11/site-packages (from yfinance) (2.0.3)
# Requirement already satisfied: numpy>=1.16.5 in /Users/alihan/anaconda3/lib/python3.11/site-packages (from yfinance) (1.24.3)
# Requirement already satisfied: requests>=2.31 in /Users/alihan/anaconda3/lib/python3.11/site-packages (from yfinance) (2.31.0)
# Requirement already satisfied: multitasking>=0.0.7 in /Users/alihan/anaconda3/lib/python3.11/site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in /Users/alihan/anaconda3/lib/python3.11/site-packages (from yfinance) (4.9.3)
# Requirement already satisfied: appdirs>=1.4.4 in /Users/alihan/anaconda3/lib/python3.11/site-packages (from yfinance) (1.4.4)
# Requirement already satisfied: pytz>=2022.5 in /Users/alihan/anaconda3/lib/python3.11/site-packages (from yfinance) (2023.3.post1)
# Requirement already satisfied: frozendict>=2.3.4 in /Users/alihan/anaconda3/lib/python3.11/site-packages (from yfinance) (2.4.1)
# Requirement already satisfied: peewee>=3.16.2 in /Users/alihan/anaconda3/lib/python3.11/site-packages (from yfinance) (3.17.1)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /Users/alihan/anaconda3/lib/python3.11/site-packages (from yfinance) (4.12.2)
# Requirement already satisfied: html5lib>=1.1 in /Users/alihan/anaconda3/lib/python3.11/site-packages (from yfinance) (1.1)
# Requirement already satisfied: soupsieve>1.2 in /Users/alihan/anaconda3/lib/python3.11/site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.4)
# Requirement already satisfied: six>=1.9 in /Users/alihan/anaconda3/lib/python3.11/site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in /Users/alihan/anaconda3/lib/python3.11/site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/alihan/anaconda3/lib/python3.11/site-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: tzdata>=2022.1 in /Users/alihan/anaconda3/lib/python3.11/site-packages (from pandas>=1.3.0->yfinance) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/alihan/anaconda3/lib/python3.11/site-packages (from requests>=2.31->yfinance) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/alihan/anaconda3/lib/python3.11/site-packages (from requests>=2.31->yfinance) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/alihan/anaconda3/lib/python3.11/site-packages (from requests>=2.31->yfinance) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/alihan/anaconda3/lib/python3.11/site-packages (from requests>=2.31->yfinance) (2023.11.17)

# %%
data = yf.download('AAPL',  '2016-01-01',  '2019-08-25')
 
df =pd.DataFrame(data)
 
df.head()
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2016-01-04  25.652500  26.342501  25.500000  26.337500  23.946918  270597600
# 2016-01-05  26.437500  26.462500  25.602501  25.677500  23.346827  223164000
# 2016-01-06  25.139999  25.592501  24.967501  25.174999  22.889935  273829600
# 2016-01-07  24.670000  25.032499  24.107500  24.112499  21.923876  324377600
# 2016-01-08  24.637501  24.777500  24.190001  24.240000  22.039803  283192000

# %%
df.shape
# Out:
# (917, 6)

# %%
df.describe().T
# Out:
#            count          mean           std           min           25%  \
# Open       917.0  3.875030e+01  9.557526e+00  2.250000e+01  2.884500e+01
# High       917.0  3.909541e+01  9.663354e+00  2.291750e+01  2.908250e+01
# Low        917.0  3.842871e+01  9.454082e+00  2.236750e+01  2.868000e+01
# Close      917.0  3.877278e+01  9.552587e+00  2.258500e+01  2.895500e+01
# Adj Close  917.0  3.664399e+01  9.544253e+00  2.077216e+01  2.682829e+01
# Volume     917.0  1.299439e+08  5.898968e+07  4.544800e+07  9.097520e+07
#
#                     50%           75%           max
# Open       3.963250e+01  4.630750e+01  5.769500e+01
# High       4.000000e+01  4.680000e+01  5.836750e+01
# Low        3.918000e+01  4.595000e+01  5.744500e+01
# Close      3.948000e+01  4.637500e+01  5.801750e+01
# Adj Close  3.746931e+01  4.423483e+01  5.542149e+01
# Volume     1.135284e+08  1.503472e+08  5.334788e+08

# %%
Close = df["Close"]

# %%
Close
# Out:
# Date
# 2016-01-04    26.337500
# 2016-01-05    25.677500
# 2016-01-06    25.174999
# 2016-01-07    24.112499
# 2016-01-08    24.240000
#                 ...
# 2019-08-19    52.587502
# 2019-08-20    52.590000
# 2019-08-21    53.160000
# 2019-08-22    53.115002
# 2019-08-23    50.660000
# Name: Close, Length: 917, dtype: float64

# %%
Close.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
Close.index
# Out:
# DatetimeIndex(['2016-01-04', '2016-01-05', '2016-01-06', '2016-01-07',
#                '2016-01-08', '2016-01-11', '2016-01-12', '2016-01-13',
#                '2016-01-14', '2016-01-15',
#                ...
#                '2019-08-12', '2019-08-13', '2019-08-14', '2019-08-15',
#                '2019-08-16', '2019-08-19', '2019-08-20', '2019-08-21',
#                '2019-08-22', '2019-08-23'],
#               dtype='datetime64[ns]', name='Date', length=917, freq=None)

# %%
DatetimeIndex = pd.DatetimeIndex(Close.index)

# %%
Close.head()
# Out:
# Date
# 2016-01-04    26.337500
# 2016-01-05    25.677500
# 2016-01-06    25.174999
# 2016-01-07    24.112499
# 2016-01-08    24.240000
# Name: Close, dtype: float64

# %%
Close.plot()
# Out:
# <Axes: xlabel='Date'>
